# %%
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data = pd.read_csv('C:/Users/xuziq/Desktop/correlation/datasets_test.csv')

# %%
data
# Out:
#       R    G    B  Output
# 0   209  101   95       8
# 1   150   11   30      40
# 2   146    9   29      44
# 3   207  101   94       7
# 4    96    2   11      60
# 5   155   19   34      35
# 6   155   12   28      45
# 7   142    3   23      46
# 8   196   67   68      15
# 9   164   39   51      40
# 10  141    4   26      55
# 11  203  115  106       5
# 12  118    9   25      51
# 13  189   54   57      19
# 14  173   28   39      36
# 15  189   61   63      15
# 16  166   29   39      31
# 17  178   36   46      32
# 18  188   55   60      19
# 19  165   34   47      39
# 20  146    4   23      54
# 21  131   12   28      49
# 22  186   52   56      15
# 23  203   88   78       6
# 24  196   81   76       7
# 25  161   21   34      43
# 26  198   86   76       6
# 27  207  103   91       5
# 28  176   33   43      25
# 29  204  104   95       5
# 30  155   15   32      45
# 31   80    4   18      56
# 32  168   26   40      40

# %%
data.plot(kind='scatter', x='R', y='G')
plt.show()

# %%
x = data['R']
y = data['G']
z = data['B']

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

ax.scatter(x,y,z)
plt.show()

# %%
data.corr()
# Out:
#                R         G         B    Output
# R       1.000000  0.862231  0.881977 -0.917806
# G       0.862231  1.000000  0.993752 -0.950201
# B       0.881977  0.993752  1.000000 -0.942978
# Output -0.917806 -0.950201 -0.942978  1.000000

# %%
R = pd.DataFrame(data['R'])
G = pd.DataFrame(data['G'])
B = pd.DataFrame(data['B'])
Output = pd.DataFrame(data['Output'])
Output
# Out:
#     Output
# 0        8
# 1       40
# 2       44
# 3        7
# 4       60
# 5       35
# 6       45
# 7       46
# 8       15
# 9       40
# 10      55
# 11       5
# 12      51
# 13      19
# 14      36
# 15      15
# 16      31
# 17      32
# 18      19
# 19      39
# 20      54
# 21      49
# 22      15
# 23       6
# 24       7
# 25      43
# 26       6
# 27       5
# 28      25
# 29       5
# 30      45
# 31      56
# 32      40

# %%
lm = linear_model.LinearRegression()
model = lm.fit(R.values,Output.values)

# %%
model.coef_
# Out:
# array([[-0.52181936]])

# %%
model.score(R,Output)
# Out:
# C:\Users\xuziq\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# 0.8423685211282659

# %%
X = ([162,147,157,143,172])
# 40,42,50,50,36
X = pd.DataFrame(X)
Y = model.predict(X)
Y = pd.DataFrame(Y)
df = pd.concat([X,Y], axis=1, keys=['R', 'Output'])
df
# Out:
#      R     Output
#      0          0
# 0  162  33.325902
# 1  147  41.153193
# 2  157  35.934999
# 3  143  43.240470
# 4  172  28.107709
